# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([3, 5,])
ypoints = np.array([8, 9])

plt.plot(xpoints, ypoints, 'o' )
plt.xlabel("Xlabel",color ='g' )
plt.ylabel("Ylabel", color='r')
plt.suptitle("Title 1")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np 
plt.suptitle("Graphs and Diagrams")
xpoint = np.array([2,5])
ypoint = np.array([2,8])


plt.subplot(3,3,1)
plt.title("graph1")
plt.plot(xpoint, ypoint, 'o')

plt.xlabel("Xlabel",color ='b' )
plt.ylabel("Ylabel", color='r')
plt.suptitle("Title 1")

x1point = np.array([0, 1, 2, 3])
y1point = np.array([3, 8, 1, 10])

x2point = np.array([0, 1, 2, 3])
y2point = np.array([6, 4, 6, 3])

plt.subplot(3,3,2)
plt.plot(x1point, y1point, marker='*', linewidth=5.5)
plt.plot(x2point, y2point, linestyle='dotted')

plt.subplot(3,3,2)

x1point = np.array([0, 1, 2, 3])
y1point = np.array([3, 8, 1, 10])

plt.subplot(3,3,3)
plt.plot(x1point, y1point, marker='o', ms=10, mfc='yellow', mec='black')

xpoint = np.array([2,5])
ypoint = np.array([2,8])

plt.subplot(3,3,4)
plt.title("GRAPH2")
plt.plot(xpoint, ypoint)
plt.grid()

plt.subplot(3,3,5) 
x3 = np.array([5,7,8,7,2])
y3 = np.array([99,86,87,88,111])
plt.scatter(x3, y3)

x4 = np.array([6,7,10,3,8])
y4 = np.array([55,87,88,83,101])
plt.scatter(x4, y4, color='blue')

plt.subplot(3,3,5) 
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])
plt.bar(x, y, color='g')

plt.subplot(3,3,6)
xd = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
yd = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(xd, yd, color='y')

xd = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
yd = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(xd, yd, color='r')

y = np.array([35, 25, 25, 15])
mylabels = ["berry", "Banana", "Apple", "Cherry"]

explode = [0.1, 0, 0, 0] 

plt.subplot(3, 3, 7)
plt.pie(
    y,
    labels=mylabels,
    colors=mycolors,
    explode=explode,
    shadow=True,
    startangle=30,
    autopct='%1.1f%%'
)
plt.legend(title="Fruits",loc= "upper right")

x = np.random.normal(50, 10, 100)
plt.subplot(3,3,9)
plt.hist(x)
plt.tight_layout()
plt.show()
